# %%
import pandas as pd
import numpy as np

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### Greedy Epsilon Q-Learning

# %%
# Epsilon value 0 till 1.
# Load the data.
df_0 = pd.read_csv('./Evaluate Maze/Greedy Epsilon Q-Learning/simpleQ_0.csv')
df_1 = pd.read_csv('./Evaluate Maze/Greedy Epsilon Q-Learning/simpleQ_1.csv')
df_2 = pd.read_csv('./Evaluate Maze/Greedy Epsilon Q-Learning/simpleQ_2.csv')
df_3 = pd.read_csv('./Evaluate Maze/Greedy Epsilon Q-Learning/simpleQ_3.csv')
df_4 = pd.read_csv('./Evaluate Maze/Greedy Epsilon Q-Learning/simpleQ_4.csv')
df_5 = pd.read_csv('./Evaluate Maze/Greedy Epsilon Q-Learning/simpleQ_5.csv')
df_6 = pd.read_csv('./Evaluate Maze/Greedy Epsilon Q-Learning/simpleQ_6.csv')
df_7 = pd.read_csv('./Evaluate Maze/Greedy Epsilon Q-Learning/simpleQ_7.csv')
df_8 = pd.read_csv('./Evaluate Maze/Greedy Epsilon Q-Learning/simpleQ_8.csv')
df_9 = pd.read_csv('./Evaluate Maze/Greedy Epsilon Q-Learning/simpleQ_9.csv')
df_10 = pd.read_csv('./Evaluate Maze/Greedy Epsilon Q-Learning/simpleQ_10.csv')

# %%
array = []
cols = ['Epsilon', 'Average Reward']

# %%
array.append([0.0, df_0['Reward'].sum()/30])
array.append([0.1, df_1['Reward'].sum()/30])
array.append([0.2, df_2['Reward'].sum()/30])
array.append([0.3, df_3['Reward'].sum()/30])
array.append([0.4, df_4['Reward'].sum()/30])
array.append([0.5, df_5['Reward'].sum()/30])
array.append([0.6, df_6['Reward'].sum()/30])
array.append([0.7, df_7['Reward'].sum()/30])
array.append([0.8, df_8['Reward'].sum()/30])
array.append([0.9, df_9['Reward'].sum()/30])
array.append([1.0, df_10['Reward'].sum()/30])

# %%
greedyEpsilon = pd.DataFrame(array, columns = cols)
greedyEpsilon
# Out:
#     Epsilon  Average Reward
# 0       0.0     -110.700000
# 1       0.1     -481.666667
# 2       0.2     -439.233333
# 3       0.3     -575.566667
# 4       0.4     -502.366667
# 5       0.5      -59.033333
# 6       0.6     -498.800000
# 7       0.7     -462.033333
# 8       0.8       54.066667
# 9       0.9     -544.900000
# 10      1.0     -494.566667

# %%
# Highest is 0.7
greedyEpsilon['Average Reward'].max()
# Out:
# 54.06666666666667

# %% [markdown]
# ### Select the best and re-train again (Up to 100 times)

# %%
df_sql = pd.read_csv('./Evaluate Maze/simpleQ_07_M1.csv')
df_sql
# Out:
#     Number of attempt   Reward  Time taken  Number of actions
# 0                   0   -141.0  358.373401               1141
# 1                   1  11671.0  274.903452                830
# 2                   2   1454.0  360.439513               1047
# 3                   3  10726.0   97.673492                274
# 4                   4   1036.0  360.629170                965
# ..                ...      ...         ...                ...
# 95                 95    642.0  147.167989                359
# 96                 96   1120.0  360.413015                881
# 97                 97   1515.0  199.358240                486
# 98                 98    620.0  360.317204                880
# 99                 99   1121.0  360.590279                880
#
# [100 rows x 4 columns]

# %%
averageReward = df_sql['Reward'].sum()/100
averageReward
# Out:
# 2772.74

# %%
success = df_sql[df_sql['Time taken'] < 355]

# Trials that agent managed to find the BIG reward/end the game.
len(success)
# Out:
# 29

# %% [markdown]
# #### Reward for every trials

# %%
plt.plot(df_sql['Number of attempt'], df_sql['Reward'])
plt.title('Rewards based on each trials')
plt.xlabel('Number of attempt')
plt.ylabel('Reward')
plt.show()

# %% [markdown]
# #### Total time taken to complete for every trials

# %%
plt.plot(df_sql['Number of attempt'], df_sql['Time taken'])
plt.title('Total time used on each trials')
plt.xlabel('Number of attempt')
plt.ylabel('Time (minutes)')
plt.show()

# %% [markdown]
# #### Time taken versus reward

# %%
sns.relplot(x = 'Reward', y = 'Time taken', hue = "Reward", data = df_sql)

# %% [markdown]
# ### Reward Based Greedy Epsilon Q-Learning

# %%
# Epsilon value 0 till 1.
# Load the data.
df_0 = pd.read_csv('./Evaluate Maze/Reward-Based Greedy Epsilon Q-Learning/Greedy-Epsilon_0.csv')
df_1 = pd.read_csv('./Evaluate Maze/Reward-Based Greedy Epsilon Q-Learning/Greedy-Epsilon_1.csv')
df_2 = pd.read_csv('./Evaluate Maze/Reward-Based Greedy Epsilon Q-Learning/Greedy-Epsilon_2.csv')
df_3 = pd.read_csv('./Evaluate Maze/Reward-Based Greedy Epsilon Q-Learning/Greedy-Epsilon_3.csv')
df_4 = pd.read_csv('./Evaluate Maze/Reward-Based Greedy Epsilon Q-Learning/Greedy-Epsilon_4.csv')
df_5 = pd.read_csv('./Evaluate Maze/Reward-Based Greedy Epsilon Q-Learning/Greedy-Epsilon_5.csv')
df_6 = pd.read_csv('./Evaluate Maze/Reward-Based Greedy Epsilon Q-Learning/Greedy-Epsilon_6.csv')
df_7 = pd.read_csv('./Evaluate Maze/Reward-Based Greedy Epsilon Q-Learning/Greedy-Epsilon_7.csv')
df_8 = pd.read_csv('./Evaluate Maze/Reward-Based Greedy Epsilon Q-Learning/Greedy-Epsilon_8.csv')
df_9 = pd.read_csv('./Evaluate Maze/Reward-Based Greedy Epsilon Q-Learning/Greedy-Epsilon_9.csv')
df_10 = pd.read_csv('./Evaluate Maze/Reward-Based Greedy Epsilon Q-Learning/Greedy-Epsilon_10.csv')

# %%
array = []
cols = ['Epsilon', 'Average Reward']

# %%
array.append([0.0, df_0['Reward'].sum()/30])
array.append([0.1, df_1['Reward'].sum()/30])
array.append([0.2, df_2['Reward'].sum()/30])
array.append([0.3, df_3['Reward'].sum()/30])
array.append([0.4, df_4['Reward'].sum()/30])
array.append([0.5, df_5['Reward'].sum()/30])
array.append([0.6, df_6['Reward'].sum()/30])
array.append([0.7, df_7['Reward'].sum()/30])
array.append([0.8, df_8['Reward'].sum()/30])
array.append([0.9, df_9['Reward'].sum()/30])
array.append([1.0, df_10['Reward'].sum()/30])

# %%
rewardGreedyEpsilon = pd.DataFrame(array, columns = cols)
rewardGreedyEpsilon
# Out:
#     Epsilon  Average Reward
# 0       0.0       15.200000
# 1       0.1     -499.266667
# 2       0.2     -368.766667
# 3       0.3       -3.866667
# 4       0.4     -378.666667
# 5       0.5     -249.566667
# 6       0.6     -372.566667
# 7       0.7       48.933333
# 8       0.8     -472.566667
# 9       0.9     -629.300000
# 10      1.0     -105.466667

# %%
# Highest is 0.7
rewardGreedyEpsilon['Average Reward'].max()
# Out:
# 48.93333333333333

# %% [markdown]
# ### Select the best and re-train again (Up to 100 times)

# %%
df_rge = pd.read_csv('./Evaluate Maze/GreedyEpsilon_07_M1.csv')
df_rge
# Out:
#     Number of attempt   Reward  Time taken  Number of actions
# 0                   0  11169.0  101.789448                331
# 1                   1   1390.0  360.158525               1110
# 2                   2   1985.0  360.470401               1016
# 3                   3   1026.0  360.203047                974
# 4                   4   -460.0  360.513818                961
# ..                ...      ...         ...                ...
# 95                 95   1117.0  360.327023                883
# 96                 96   -380.0  360.238932                880
# 97                 97   2120.0  360.155117                880
# 98                 98    619.0  360.498610                882
# 99                 99   2620.0  360.389796                881
#
# [100 rows x 4 columns]

# %%
averageReward = df_rge['Reward'].sum()/100
averageReward
# Out:
# 2826.13

# %%
success = df_rge[df_rge['Time taken'] < 355]

# Trials that agent managed to find the BIG reward/end the game.
len(success)
# Out:
# 19

# %% [markdown]
# #### Rewards for every trials

# %%
plt.plot(df_rge['Number of attempt'], df_rge['Reward'])
plt.title('Rewards based on each trials')
plt.xlabel('Number of attempt')
plt.ylabel('Reward')
plt.show()

# %% [markdown]
# #### Total time taken to complete for every trials

# %%
plt.plot(df_rge['Number of attempt'], df_rge['Time taken'])
plt.title('Total time used on each trials')
plt.xlabel('Number of attempt')
plt.ylabel('Time (minutes)')
plt.show()

# %% [markdown]
# #### Time taken versus reward

# %%
sns.relplot(x = 'Reward', y = 'Time taken', hue = "Reward", data = df_rge)

# %% [markdown]
# ### Q-Learning With Learning Parameter

# %%
# Epsilon value 0 till 1.
# Alpha = 0.1
# Gamma = 0.1
# Load the data.
df_0 = pd.read_csv('./Evaluate Maze/Three learning parameters Q-Learning/E0A1G1.csv')
df_1 = pd.read_csv('./Evaluate Maze/Three learning parameters Q-Learning/E1A1G1.csv')
df_2 = pd.read_csv('./Evaluate Maze/Three learning parameters Q-Learning/E2A1G1.csv')
df_3 = pd.read_csv('./Evaluate Maze/Three learning parameters Q-Learning/E3A1G1.csv')
df_4 = pd.read_csv('./Evaluate Maze/Three learning parameters Q-Learning/E4A1G1.csv')
df_5 = pd.read_csv('./Evaluate Maze/Three learning parameters Q-Learning/E5A1G1.csv')
df_6 = pd.read_csv('./Evaluate Maze/Three learning parameters Q-Learning/E6A1G1.csv')
df_7 = pd.read_csv('./Evaluate Maze/Three learning parameters Q-Learning/E7A1G1.csv')
df_8 = pd.read_csv('./Evaluate Maze/Three learning parameters Q-Learning/E8A1G1.csv')
df_9 = pd.read_csv('./Evaluate Maze/Three learning parameters Q-Learning/E9A1G1.csv')
df_10 = pd.read_csv('./Evaluate Maze/Three learning parameters Q-Learning/E10A1G1.csv')

# %%
array = []
cols = ['Epsilon', 'Average Reward']

# %%
array.append([0.0, df_0['Reward'].sum()/30])
array.append([0.1, df_1['Reward'].sum()/30])
array.append([0.2, df_2['Reward'].sum()/30])
array.append([0.3, df_3['Reward'].sum()/30])
array.append([0.4, df_4['Reward'].sum()/30])
array.append([0.5, df_5['Reward'].sum()/30])
array.append([0.6, df_6['Reward'].sum()/30])
array.append([0.7, df_7['Reward'].sum()/30])
array.append([0.8, df_8['Reward'].sum()/30])
array.append([0.9, df_9['Reward'].sum()/30])
array.append([1.0, df_10['Reward'].sum()/30])

# %%
advancedQ = pd.DataFrame(array, columns = cols)
advancedQ
# Out:
#     Epsilon  Average Reward
# 0       0.0       -5.166667
# 1       0.1        7.300000
# 2       0.2     -459.966667
# 3       0.3     -405.900000
# 4       0.4     -472.633333
# 5       0.5      290.700000
# 6       0.6      -93.066667
# 7       0.7     -563.900000
# 8       0.8     -568.900000
# 9       0.9     -418.033333
# 10      1.0     -114.966667

# %%
# Highest is 0.5
advancedQ['Average Reward'].max()
# Out:
# 290.7

# %% [markdown]
# ### Select the best and re-train again (Up to 100 times)

# %%
df_pq = pd.read_csv('./Evaluate Maze/E5A01_M1.csv')
df_pq
# Out:
#     Number of attempt   Reward  Time taken  Number of actions
# 0                   0    831.0  360.123954               1169
# 1                   1   -593.0  360.430502               1094
# 2                   2  11351.0   50.024292                149
# 3                   3   1969.0  360.156113               1031
# 4                   4    496.0  360.545717               1005
# ..                ...      ...         ...                ...
# 95                 95   1094.0  360.244082                906
# 96                 96   1596.0  360.274010                904
# 97                 97   1094.0  360.215484                906
# 98                 98   1094.0  360.473669                907
# 99                 99   1094.0  360.490247                907
#
# [100 rows x 4 columns]

# %%
averageReward = df_pq['Reward'].sum()/100
averageReward
# Out:
# 2920.22

# %%
success = df_pq[df_pq['Time taken'] < 355]

# Trials that agent managed to find the BIG reward/end the game.
len(success)
# Out:
# 21

# %% [markdown]
# #### Rewards for every trials

# %%
plt.plot(df_pq['Number of attempt'], df_pq['Reward'])
plt.title('Rewards based on each trials')
plt.xlabel('Number of attempt')
plt.ylabel('Reward')
plt.show()

# %% [markdown]
# #### Total time taken to complete for every trials

# %%
plt.plot(df_pq['Number of attempt'], df_pq['Time taken'])
plt.title('Total time used on each trials')
plt.xlabel('Number of attempt')
plt.ylabel('Time (minutes)')
plt.show()

# %% [markdown]
# #### Time taken versus reward

# %%
sns.relplot(x = 'Reward', y = 'Time taken', hue = "Reward", data = df_pq)

# %% [markdown]
# ### Deep Q Network

# %%
# Epsilon value 0 till 1.
# Epsilon decay = 0.45
# Gamma = 0.1
# Load the data.
df_0 = pd.read_csv('./Evaluate Maze/Deep Q Network/DQN_E0_M1.csv')
df_1 = pd.read_csv('./Evaluate Maze/Deep Q Network/DQN_E1_M1.csv')
df_2 = pd.read_csv('./Evaluate Maze/Deep Q Network/DQN_E2_M1.csv')
df_3 = pd.read_csv('./Evaluate Maze/Deep Q Network/DQN_E3_M1.csv')
df_4 = pd.read_csv('./Evaluate Maze/Deep Q Network/DQN_E4_M1.csv')
df_5 = pd.read_csv('./Evaluate Maze/Deep Q Network/DQN_E5_M1.csv')
df_6 = pd.read_csv('./Evaluate Maze/Deep Q Network/DQN_E6_M1.csv')
df_7 = pd.read_csv('./Evaluate Maze/Deep Q Network/DQN_E7_M1.csv')
df_8 = pd.read_csv('./Evaluate Maze/Deep Q Network/DQN_E8_M1.csv')
df_9 = pd.read_csv('./Evaluate Maze/Deep Q Network/DQN_E9_M1.csv')

# %%
array = []
cols = ['Epsilon', 'Average Reward']

# %%
array.append([0.0, df_0['Reward'].sum()/100])
array.append([0.1, df_1['Reward'].sum()/100])
array.append([0.2, df_2['Reward'].sum()/100])
array.append([0.3, df_3['Reward'].sum()/100])
array.append([0.4, df_4['Reward'].sum()/100])
array.append([0.5, df_5['Reward'].sum()/100])
array.append([0.6, df_6['Reward'].sum()/100])
array.append([0.7, df_7['Reward'].sum()/100])
array.append([0.8, df_8['Reward'].sum()/100])
array.append([0.9, df_9['Reward'].sum()/100])

# %%
DQN = pd.DataFrame(array, columns = cols)
DQN
# Out:
#    Epsilon  Average Reward
# 0      0.0       -12320.70
# 1      0.1        -2779.80
# 2      0.2       -11942.62
# 3      0.3          258.50
# 4      0.4        -1676.71
# 5      0.5       -12372.89
# 6      0.6         -503.18
# 7      0.7        -1572.46
# 8      0.8       -10986.10
# 9      0.9       -13150.02

# %%
# Highest is 0.3
DQN['Average Reward'].max()
# Out:
# 258.5

# %%
# Lowest is 0.9
DQN['Average Reward'].min()
# Out:
# -13150.02

# %% [markdown]
# ### DQN with Espilon = 0.3

# %%
df_3
# Out:
#     Number of attempt  Reward  Time taken  Number of actions
# 0                   0   -4171  360.200943               1812
# 1                   1   -4460  360.217141               2652
# 2                   2    7596  230.118759               4398
# 3                   3   -5734  360.200045               6956
# 4                   4   -5481  360.203998               6729
# ..                ...     ...         ...                ...
# 95                 95   -4992  360.227426               5827
# 96                 96    9358   97.217013               1487
# 97                 97   -3502  360.241627               5864
# 98                 98   -4029  360.358098               5834
# 99                 99   -2872  360.291791               5736
#
# [100 rows x 4 columns]

# %%
averageReward = df_3['Reward'].sum()/100
averageReward
# Out:
# 258.5

# %%
success = df_3[df_3['Time taken'] < 355]

# Trials that agent managed to find the BIG reward/end the game.
len(success)
# Out:
# 35

# %% [markdown]
# #### Rewards for every trials

# %%
plt.plot(df_3['Number of attempt'], df_3['Reward'])
plt.title('Rewards based on each trials')
plt.xlabel('Number of attempt')
plt.ylabel('Reward')
plt.show()

# %% [markdown]
# #### Total time taken to complete for every trials

# %%
plt.plot(df_3['Number of attempt'], df_3['Time taken'])
plt.title('Total time used on each trials')
plt.xlabel('Number of attempt')
plt.ylabel('Time (minutes)')
plt.show()

# %% [markdown]
# #### Time taken versus reward

# %%
sns.relplot(x = 'Reward', y = 'Time taken', hue = "Reward", data = df_3)
