# %%
import pandas as pd
import numpy as np

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### Greedy Epsilon Q-Learning

# %%
# Epsilon value 0 till 1.
# Load the data.
df_0 = pd.read_csv('./Random Maze/Greedy Epsilon Q-Learning/simpleQ_00_M2.csv')
df_1 = pd.read_csv('./Random Maze/Greedy Epsilon Q-Learning/simpleQ_01_M2.csv')
df_2 = pd.read_csv('./Random Maze/Greedy Epsilon Q-Learning/simpleQ_02_M2.csv')
df_3 = pd.read_csv('./Random Maze/Greedy Epsilon Q-Learning/simpleQ_03_M2.csv')
df_4 = pd.read_csv('./Random Maze/Greedy Epsilon Q-Learning/simpleQ_04_M2.csv')
df_5 = pd.read_csv('./Random Maze/Greedy Epsilon Q-Learning/simpleQ_05_M2.csv')
df_6 = pd.read_csv('./Random Maze/Greedy Epsilon Q-Learning/simpleQ_06_M2.csv')
df_7 = pd.read_csv('./Random Maze/Greedy Epsilon Q-Learning/simpleQ_07_M2.csv')
df_8 = pd.read_csv('./Random Maze/Greedy Epsilon Q-Learning/simpleQ_08_M2.csv')
df_9 = pd.read_csv('./Random Maze/Greedy Epsilon Q-Learning/simpleQ_09_M2.csv')
df_10 = pd.read_csv('./Random Maze/Greedy Epsilon Q-Learning/simpleQ_10_M2.csv')

# %%
array = []
cols = ['Epsilon', 'Average Reward']

# %%
array.append([0.0, df_0['Reward'].sum()/30])
array.append([0.1, df_1['Reward'].sum()/30])
array.append([0.2, df_2['Reward'].sum()/30])
array.append([0.3, df_3['Reward'].sum()/30])
array.append([0.4, df_4['Reward'].sum()/30])
array.append([0.5, df_5['Reward'].sum()/30])
array.append([0.6, df_6['Reward'].sum()/30])
array.append([0.7, df_7['Reward'].sum()/30])
array.append([0.8, df_8['Reward'].sum()/30])
array.append([0.9, df_9['Reward'].sum()/30])
array.append([1.0, df_10['Reward'].sum()/30])

# %%
greedyEpsilon = pd.DataFrame(array, columns = cols)
greedyEpsilon
# Out:
#     Epsilon  Average Reward
# 0       0.0      409.466667
# 1       0.1     2998.933333
# 2       0.2     2450.233333
# 3       0.3     3145.966667
# 4       0.4     1487.133333
# 5       0.5      682.833333
# 6       0.6     1951.233333
# 7       0.7     2686.866667
# 8       0.8     1004.233333
# 9       0.9     3088.033333
# 10      1.0     3219.533333

# %%
# Highest is 1.0
greedyEpsilon['Average Reward'].max()
# Out:
# 3219.5333333333333

# %% [markdown]
# ### Select the best and re-train again (Up to 100 times)

# %%
df_sql = pd.read_csv('./Random Maze/simpleQ_10_M2_F.csv')
df_sql
# Out:
#     Number of attempt   Reward  Time taken  Number of actions
# 0                   0    351.0   43.353162                149
# 1                   1  10343.0   50.681166                157
# 2                   2  10860.0   46.327236                141
# 3                   3  11481.0    6.216648                 19
# 4                   4   1427.0  360.249896               1073
# ..                ...      ...         ...                ...
# 95                 95   9631.0  185.379190                370
# 96                 96   2464.0   18.997283                 37
# 97                 97    107.0  197.244431                394
# 98                 98   -180.0   90.380755                180
# 99                 99    263.0  119.231537                238
#
# [100 rows x 4 columns]

# %%
averageReward = df_sql['Reward'].sum()/100
averageReward
# Out:
# 3920.33

# %%
success = df_sql[df_sql['Time taken'] < 355]

# Trials that agent managed to find the BIG reward/end the game.
len(success)
# Out:
# 79

# %% [markdown]
# #### Reward for every trials

# %%
plt.plot(df_sql['Number of attempt'], df_sql['Reward'])
plt.title('Rewards based on each trials')
plt.xlabel('Number of attempt')
plt.ylabel('Reward')
plt.show()

# %% [markdown]
# #### Total time taken to complete for every trials

# %%
plt.plot(df_sql['Number of attempt'], df_sql['Time taken'])
plt.title('Total time used on each trials')
plt.xlabel('Number of attempt')
plt.ylabel('Time (minutes)')
plt.show()

# %% [markdown]
# #### Time taken versus reward

# %%
sns.relplot(x = 'Reward', y = 'Time taken', hue = "Reward", data = df_sql)

# %% [markdown]
# ### Reward Based Greedy Epsilon Q-Learning

# %%
# Epsilon value 0 till 1.
# Load the data.
df_0 = pd.read_csv('./Random Maze/Reward-Based Greedy Epsilon Q-Learning/GreedyEpsilon_00_M2.csv')
df_1 = pd.read_csv('./Random Maze/Reward-Based Greedy Epsilon Q-Learning/GreedyEpsilon_01_M2.csv')
df_2 = pd.read_csv('./Random Maze/Reward-Based Greedy Epsilon Q-Learning/GreedyEpsilon_02_M2.csv')
df_3 = pd.read_csv('./Random Maze/Reward-Based Greedy Epsilon Q-Learning/GreedyEpsilon_03_M2.csv')
df_4 = pd.read_csv('./Random Maze/Reward-Based Greedy Epsilon Q-Learning/GreedyEpsilon_04_M2.csv')
df_5 = pd.read_csv('./Random Maze/Reward-Based Greedy Epsilon Q-Learning/GreedyEpsilon_05_M2.csv')
df_6 = pd.read_csv('./Random Maze/Reward-Based Greedy Epsilon Q-Learning/GreedyEpsilon_06_M2.csv')
df_7 = pd.read_csv('./Random Maze/Reward-Based Greedy Epsilon Q-Learning/GreedyEpsilon_07_M2.csv')
df_8 = pd.read_csv('./Random Maze/Reward-Based Greedy Epsilon Q-Learning/GreedyEpsilon_08_M2.csv')
df_9 = pd.read_csv('./Random Maze/Reward-Based Greedy Epsilon Q-Learning/GreedyEpsilon_09_M2.csv')
df_10 = pd.read_csv('./Random Maze/Reward-Based Greedy Epsilon Q-Learning/GreedyEpsilon_10_M2.csv')

# %%
array = []
cols = ['Epsilon', 'Average Reward']

# %%
array.append([0.0, df_0['Reward'].sum()/30])
array.append([0.1, df_1['Reward'].sum()/30])
array.append([0.2, df_2['Reward'].sum()/30])
array.append([0.3, df_3['Reward'].sum()/30])
array.append([0.4, df_4['Reward'].sum()/30])
array.append([0.5, df_5['Reward'].sum()/30])
array.append([0.6, df_6['Reward'].sum()/30])
array.append([0.7, df_7['Reward'].sum()/30])
array.append([0.8, df_8['Reward'].sum()/30])
array.append([0.9, df_9['Reward'].sum()/30])
array.append([1.0, df_10['Reward'].sum()/30])

# %%
rewardGreedyEpsilon = pd.DataFrame(array, columns = cols)
rewardGreedyEpsilon
# Out:
#     Epsilon  Average Reward
# 0       0.0     2162.366667
# 1       0.1     2784.066667
# 2       0.2     1694.900000
# 3       0.3     2755.533333
# 4       0.4     2134.700000
# 5       0.5     1699.000000
# 6       0.6     -408.133333
# 7       0.7     2950.266667
# 8       0.8     2631.300000
# 9       0.9     2020.166667
# 10      1.0     -381.266667

# %%
# Highest is 0.7
rewardGreedyEpsilon['Average Reward'].max()
# Out:
# 2950.266666666667

# %% [markdown]
# ### Select the best and re-train again (Up to 100 times)

# %%
df_rge = pd.read_csv('./Random Maze/GreedyEpsilon_07_M2_F.csv')
df_rge
# Out:
#     Number of attempt   Reward  Time taken  Number of actions
# 0                   0    -29.0   42.543505                 29
# 1                   1    -98.0  402.153921                598
# 2                   2    -49.0   26.916570                 50
# 3                   3     -6.0    3.965994                  7
# 4                   4  11685.0  262.927208                316
# ..                ...      ...         ...                ...
# 95                 95    417.0  114.857190                 84
# 96                 96   9725.0  386.197682                276
# 97                 97   -300.0  409.181865                301
# 98                 98    -32.0   34.038292                 33
# 99                 99    218.0  429.917252                283
#
# [100 rows x 4 columns]

# %%
averageReward = df_rge['Reward'].sum()/100
averageReward
# Out:
# 3772.26

# %%
success = df_rge[df_rge['Time taken'] < 355]

# Trials that agent managed to find the BIG reward/end the game.
len(success)
# Out:
# 65

# %% [markdown]
# #### Rewards for every trials

# %%
plt.plot(df_rge['Number of attempt'], df_rge['Reward'])
plt.title('Rewards based on each trials')
plt.xlabel('Number of attempt')
plt.ylabel('Reward')
plt.show()

# %% [markdown]
# #### Total time taken to complete for every trials

# %%
plt.plot(df_rge['Number of attempt'], df_rge['Time taken'])
plt.title('Total time used on each trials')
plt.xlabel('Number of attempt')
plt.ylabel('Time (minutes)')
plt.show()

# %% [markdown]
# #### Time taken versus reward

# %%
sns.relplot(x = 'Reward', y = 'Time taken', hue = "Reward", data = df_rge)

# %% [markdown]
# ### Q-Learning With Learning Parameter

# %%
# Epsilon value 0 till 1.
# Alpha = 0.1
# Gamma = 0.1
# Load the data.
df_0 = pd.read_csv('./Random Maze/Three learning parameters Q-Learning/E00A01G01_M2.csv')
df_1 = pd.read_csv('./Random Maze/Three learning parameters Q-Learning/E01A01G01_M2.csv')
df_2 = pd.read_csv('./Random Maze/Three learning parameters Q-Learning/E02A01G01_M2.csv')
df_3 = pd.read_csv('./Random Maze/Three learning parameters Q-Learning/E03A01G01_M2.csv')
df_4 = pd.read_csv('./Random Maze/Three learning parameters Q-Learning/E04A01G01_M2.csv')
df_5 = pd.read_csv('./Random Maze/Three learning parameters Q-Learning/E05A01G01_M2.csv')
df_6 = pd.read_csv('./Random Maze/Three learning parameters Q-Learning/E06A01G01_M2.csv')
df_7 = pd.read_csv('./Random Maze/Three learning parameters Q-Learning/E07A01G01_M2.csv')
df_8 = pd.read_csv('./Random Maze/Three learning parameters Q-Learning/E08A01G01_M2.csv')
df_9 = pd.read_csv('./Random Maze/Three learning parameters Q-Learning/E09A01G01_M2.csv')
df_10 = pd.read_csv('./Random Maze/Three learning parameters Q-Learning/E10A01G01_M2.csv')

# %%
array = []
cols = ['Epsilon', 'Average Reward']

# %%
array.append([0.0, df_0['Reward'].sum()/30])
array.append([0.1, df_1['Reward'].sum()/30])
array.append([0.2, df_2['Reward'].sum()/30])
array.append([0.3, df_3['Reward'].sum()/30])
array.append([0.4, df_4['Reward'].sum()/30])
array.append([0.5, df_5['Reward'].sum()/30])
array.append([0.6, df_6['Reward'].sum()/30])
array.append([0.7, df_7['Reward'].sum()/30])
array.append([0.8, df_8['Reward'].sum()/30])
array.append([0.9, df_9['Reward'].sum()/30])
array.append([1.0, df_10['Reward'].sum()/30])

# %%
advancedQ = pd.DataFrame(array, columns = cols)
advancedQ
# Out:
#     Epsilon  Average Reward
# 0       0.0     2574.066667
# 1       0.1     1320.166667
# 2       0.2     1765.300000
# 3       0.3     3799.966667
# 4       0.4      892.400000
# 5       0.5     2193.300000
# 6       0.6     2132.733333
# 7       0.7     2875.333333
# 8       0.8     2916.466667
# 9       0.9      908.866667
# 10      1.0     1400.666667

# %%
# Highest is 0.3
advancedQ['Average Reward'].max()
# Out:
# 3799.9666666666667

# %% [markdown]
# ### Select the best and re-train again (Up to 100 times)

# %%
df_pq = pd.read_csv('./Random Maze/E3A01_M2.csv')
df_pq
# Out:
#     Number of attempt   Reward  Time taken  Number of actions
# 0                   0  10221.0   83.246391                279
# 1                   1    -64.0   18.950086                 64
# 2                   2   -159.0  360.208997               1159
# 3                   3   -179.0   58.462456                180
# 4                   4  10174.0  108.063442                327
# ..                ...      ...         ...                ...
# 95                 95    235.0  133.806979                266
# 96                 96    782.0  360.493123                719
# 97                 97   9908.0   47.309834                 93
# 98                 98  10423.0   39.398467                 78
# 99                 99   -218.0  360.520750                719
#
# [100 rows x 4 columns]

# %%
averageReward = df_pq['Reward'].sum()/100
averageReward
# Out:
# 3582.11

# %%
success = df_pq[df_pq['Time taken'] < 355]

# Trials that agent managed to find the BIG reward/end the game.
len(success)
# Out:
# 78

# %% [markdown]
# #### Rewards for every trials

# %%
plt.plot(df_pq['Number of attempt'], df_pq['Reward'])
plt.title('Rewards based on each trials')
plt.xlabel('Number of attempt')
plt.ylabel('Reward')
plt.show()

# %% [markdown]
# #### Total time taken to complete for every trials

# %%
plt.plot(df_pq['Number of attempt'], df_pq['Time taken'])
plt.title('Total time used on each trials')
plt.xlabel('Number of attempt')
plt.ylabel('Time (minutes)')
plt.show()

# %% [markdown]
# #### Time taken versus reward

# %%
sns.relplot(x = 'Reward', y = 'Time taken', hue = "Reward", data = df_pq)

# %% [markdown]
# ### Deep Q Network

# %%
# Epsilon value 0 till 1.
# Epsilon decay = 0.45
# Gamma = 0.1
# Load the data.
df_0 = pd.read_csv('./Random Maze/Deep Q Network/DQN_E0_M2.csv')
df_1 = pd.read_csv('./Random Maze/Deep Q Network/DQN_E1_M2.csv')
df_2 = pd.read_csv('./Random Maze/Deep Q Network/DQN_E2_M2.csv')
df_3 = pd.read_csv('./Random Maze/Deep Q Network/DQN_E3_M2.csv')
df_4 = pd.read_csv('./Random Maze/Deep Q Network/DQN_E4_M2.csv')
df_5 = pd.read_csv('./Random Maze/Deep Q Network/DQN_E5_M2.csv')
df_6 = pd.read_csv('./Random Maze/Deep Q Network/DQN_E6_M2.csv')
df_7 = pd.read_csv('./Random Maze/Deep Q Network/DQN_E7_M2.csv')
df_8 = pd.read_csv('./Random Maze/Deep Q Network/DQN_E8_M2.csv')
df_9 = pd.read_csv('./Random Maze/Deep Q Network/DQN_E9_M2.csv')

# %%
array = []
cols = ['Epsilon', 'Average Reward']

# %%
array.append([0.0, df_0['Reward'].sum()/100])
array.append([0.1, df_1['Reward'].sum()/100])
array.append([0.2, df_2['Reward'].sum()/100])
array.append([0.3, df_3['Reward'].sum()/100])
array.append([0.4, df_4['Reward'].sum()/100])
array.append([0.5, df_5['Reward'].sum()/100])
array.append([0.6, df_6['Reward'].sum()/100])
array.append([0.7, df_7['Reward'].sum()/100])
array.append([0.8, df_8['Reward'].sum()/100])
array.append([0.9, df_9['Reward'].sum()/100])

# %%
DQN = pd.DataFrame(array, columns = cols)
DQN
# Out:
#    Epsilon  Average Reward
# 0      0.0        -1640.44
# 1      0.1        -5392.76
# 2      0.2        -5392.08
# 3      0.3        -5190.14
# 4      0.4        -4777.69
# 5      0.5         4011.00
# 6      0.6        -7053.43
# 7      0.7        -4682.57
# 8      0.8        -7756.71
# 9      0.9       -10916.01

# %%
# Highest is 0.5
DQN['Average Reward'].max()
# Out:
# 4011.0

# %%
# Lowest is 0.9
DQN['Average Reward'].min()
# Out:
# -10916.01

# %% [markdown]
# ### DQN with Espilon = 0.5

# %%
df_5
# Out:
#     Number of attempt  Reward  Time taken  Number of actions
# 0                   0    2156   43.383005                278
# 1                   1    6538  277.500765               2633
# 2                   2    8854   67.333470                686
# 3                   3   11167   18.736269                274
# 4                   4   -6572  360.271276               5509
# ..                ...     ...         ...                ...
# 95                 95    9888   32.418743                531
# 96                 96   11179   43.160278                711
# 97                 97   -7019  360.233879               5945
# 98                 98   -6894  360.090623               5875
# 99                 99   12920   58.676816                916
#
# [100 rows x 4 columns]

# %%
averageReward = df_5['Reward'].sum()/100
averageReward
# Out:
# 4011.0

# %%
success = df_5[df_5['Time taken'] < 355]

# Trials that agent managed to find the BIG reward/end the game.
len(success)
# Out:
# 78

# %% [markdown]
# #### Rewards for every trials

# %%
plt.plot(df_5['Number of attempt'], df_5['Reward'])
plt.title('Rewards based on each trials')
plt.xlabel('Number of attempt')
plt.ylabel('Reward')
plt.show()

# %% [markdown]
# #### Total time taken to complete for every trials

# %%
plt.plot(df_5['Number of attempt'], df_5['Time taken'])
plt.title('Total time used on each trials')
plt.xlabel('Number of attempt')
plt.ylabel('Time (minutes)')
plt.show()

# %% [markdown]
# #### Time taken versus reward

# %%
sns.relplot(y = 'Reward', x = 'Time taken', hue = "Reward", data = df_5)
